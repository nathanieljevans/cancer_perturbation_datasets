# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt

# %%
grn = pd.read_csv('../data/cancer_breast_otter_network.csv')
grn.head()S
# Out:
#       Row  ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# 0    NFYA     6.887229e-06    -7.839131e-07         0.000009     1.174730e-05
# 1     ARX     2.426024e-06    -1.812793e-06        -0.000002     2.933456e-06
# 2  HOXA11     0.000000e+00     0.000000e+00         0.000000     0.000000e+00
# 3   MEOX1    -2.866685e-07    -3.964806e-07         0.000001     7.460444e-07
# 4    SOX8     8.681359e-06     6.074230e-06        -0.000002     3.232666e-06
#
#    ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# 0         0.000014         0.000018         0.000012         0.000004
# 1        -0.000004        -0.000003         0.000004        -0.000002
# 2         0.000000         0.000000         0.000000         0.000000
# 3        -0.000002         0.000003        -0.000003         0.000002
# 4         0.000006         0.000011         0.000011         0.000007
#
# ...

# %%
grn.shape
# Out:
# (1637, 31106)
